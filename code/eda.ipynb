# %% [markdown]
# ## Univariate Analysis
#
# Create the following visualizations & measures:
#
# * distributions
# * ks-test

# %%
import pandas as pd
import matplotlib.pyplot as plt
import statistics as stats

# Load the data from CSV
data = pd.read_csv("C:/Users/TATIANNA.ANDERSON/Mini Capstone23/mini_cap/code/transformed_data.csv")

# Replace 'column_name' with the actual name of the column you want to analyze
column_name = 'SED APPROVED ESTIMATE'

# Get the data for the selected column
column_data = data['SED APPROVED ESTIMATE']

# Calculate basic statistics
mean = column_data.mean()
median = column_data.median()
std_dev = column_data.std()

# Plot the histogram to visualize the distribution
plt.figure(figsize=(8, 6))
plt.hist(column_data, bins='auto', color='blue', alpha=0.7)
plt.axvline(mean, color='red', linestyle='dashed', linewidth=2, label=f"Mean: {mean:.2f}")
plt.axvline(median, color='green', linestyle='dashed', linewidth=2, label=f"Median: {median:.2f}")
plt.xlabel(column_name)
plt.ylabel("Frequency")
plt.title(f"{column_name} Distribution")
plt.legend()
plt.grid(True)
plt.show()


#k test 

ks_stats, p_value = ks_stats(column_data, 'norm', args=(mean, std_dev))

# Print KS test (Code below)


print("KS Statistic:", ks_stats)
print("P-value:", p_value)
if p_value < 0.05:
    print("The distribution is significantly different from a normal distribution.")
else:
    print("The distribution is not significantly different from a normal distribution.")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\TATIANNA.ANDERSON\Mini Capstone23\mini_cap\code\eda.ipynb Cell 2 in 3
#      <a href='vscode-notebook-cell:/c%3A/Users/TATIANNA.ANDERSON/Mini%20Capstone23/mini_cap/code/eda.ipynb#W1sZmlsZQ%3D%3D?line=28'>29</a> plt.show()
#      <a href='vscode-notebook-cell:/c%3A/Users/TATIANNA.ANDERSON/Mini%20Capstone23/mini_cap/code/eda.ipynb#W1sZmlsZQ%3D%3D?line=31'>32</a> #k test
# ---> <a href='vscode-notebook-cell:/c%3A/Users/TATIANNA.ANDERSON/Mini%20Capstone23/mini_cap/code/eda.ipynb#W1sZmlsZQ%3D%3D?line=33'>34</a> ks_stats, p_value = stats.kstest(column_data, 'norm', args=(mean, std_dev))
#      <a href='vscode-notebook-cell:/c%3A/Users/TATIANNA.ANDERSON/Mini%20Capstone23/mini_cap/code/eda.ipynb#W1sZmlsZQ%3D%3D?line=35'>36</a> # Print KS test
# ...
